# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot
df = pd.read_csv('procedimento_ml.csv', sep = ';')
df = df[['Data', 'Brasil']]
df
# Out:
#         Data  Brasil
# 0    01/2008    9495
# 1    02/2008   18616
# 2    03/2008   19190
# 3    04/2008   17677
# 4    05/2008   18558
# ..       ...     ...
# 161  06/2021   18383
# 162  07/2021   19519
# 163  08/2021   21303
# 164  09/2021   22227
# 165  10/2021   21654
#
# [166 rows x 2 columns]

# %%
autocorrelation_plot(df['Brasil'])
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
#Convertendo a coluna Data em formato objeto para datetime
df['Data'] = pd.to_datetime(df['Data'], infer_datetime_format = True)

# %%
st = df[15:144]
real = df[144:]

# %%
split_size = int(0.8*len(st)) #Treino 80% e validação 20%

# %%
st.set_index('Data')['Brasil'].plot(subplots = True)
plt.show()

# %%
df.set_index('Data')['Brasil'].plot(subplots =True)
plt.show()

# %%
real.set_index('Data')['Brasil'].plot(subplots = True)
plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
st = np.array(st)

# %%
model = ARIMA(st, order=(5,1,0))
model_fit = model.fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-3d8b0b6cb80e> in <module>
# ----> 1 model = ARIMA(st, order=(5,1,0))
#       2 model_fit = model.fit()
#
# /usr/local/lib/python3.9/site-packages/statsmodels/tsa/arima/model.py in __init__(self, endog, exog, order, seasonal_order, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     130         # this criteria. Instead, we'll just make sure that the parameter
#     131         # estimates from those methods satisfy the criteria.)
# --> 132         self._spec_arima = SARIMAXSpecification(
#     133             endog, exog=exog, order=order, seasonal_order=seasonal_order,
#     134             trend=trend, enforce_stationarity=None, enforce_invertibility=None,
#
# ...
